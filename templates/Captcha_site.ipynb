# %%
pip install flask
pip install opencv-python
pip install numpy
python.exe -m pip install --upgrade pip
pip install mediapipe-nightly
# Out:
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# ...
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# ...
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# ...
#
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------------- ----- 6/7 [flask]
#    ---------------------------------------- 7/7 [flask]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script flask.exe is installed in 'c:\Users\tarms\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# Cell 2: If mediapipe has issues, try the nightly build
# %pip uninstall mediapipe -y
# %pip install mediapipe-nightly
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping mediapipe as it is not installed.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template, Response, jsonify, redirect, url_for
import cv2
import mediapipe as mp
import pickle
import time
import numpy as np
import random
import secrets
import re

print("✅ All imports loaded!")
# Out:
# ✅ All imports loaded!
